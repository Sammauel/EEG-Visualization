# %%
import numpy as np
import mne
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy 
from scipy.stats import hmean,trim_mean
import pandas as pd

df = pd.read_json('test.json')
df.head()
# Out:
#     0             1             2             3            4            5   \
# 0    0  11607.189936  14893.280850  15708.377604  1512.585225  6591.296067
# 1  100  11555.578653  15299.300894  15693.479940  1436.988655  6829.300896
# 2  200  11540.766520  15416.880237  15683.965824  1412.987570  6884.302009
# 3  300  11512.506610  15604.173968  15673.798529  1376.670943  7001.180145
# 4  400  11517.604170  15520.944267  15677.104511  1387.739775  6962.857434
#
#             6             7             8             9       ...       \
# 0  -898.787251  18075.431582  16503.607833  13248.552848      ...
# 1 -1011.861941  18168.177774  16772.396012  13415.294053      ...
# 2 -1041.261801  18190.168586  16843.484548  13460.361477      ...
# 3 -1100.937336  18231.458615  16965.471244  13537.960218      ...
# 4 -1087.945724  18217.714150  16920.458397  13501.012309      ...
#
#              52            53            54           55            56  \
# ...

# %%
fp1 = df.drop(df.columns[2:62], axis=1, inplace=True)

# %%
# Out:
#              0             1
# 0            0  11607.189936
# 1          100  11555.578653
# 2          200  11540.766520
# 3          300  11512.506610
# 4          400  11517.604170
# 5          500  11550.854266
# 6          600  11624.342274
# 7          700  11700.544140
# 8          800  11726.635403
# 9          900  11718.698885
# 10        1000  11711.965857
# 11        1100  11682.329261
# 12        1200  11658.595443
# 13        1300  11650.827910
# 14        1400  11649.607798
# 15        1500  11654.838807
# 16        1600  11659.355010
# 17        1700  11657.288646
# 18        1800  11646.070424
# 19        1900  11644.777372
# 20        2000  11640.201827
# 21        2100  11623.000760
# 22        2200  11600.671950
# 23        2300  11589.676330
# 24        2400  11593.505931
# 25        2500  11584.284060
# 26        2600  11578.856694
# 27        2700  11525.444082
# 28        2800  11488.939438
# 29        2900  11472.723305
# ...        ...           ...
# ...
